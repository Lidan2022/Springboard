# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# import data
df1= pd.read_csv('Youth_Risk_Behavioral_Surveillance_System__YRBSS__Data.csv')
df2= pd.read_csv('Youth_Tobacco_Survey__YTS__Data (1).csv')

# %%
df1
# Out:
#        YEAR LocationAbbr   LocationDesc                  TopicType  \
# 0      1999           MA  Massachusetts  Tobacco Use - Survey Data
# 1      2005           OH           Ohio  Tobacco Use - Survey Data
# 2      1997           IA           Iowa  Tobacco Use - Survey Data
# 3      2007           LA      Louisiana  Tobacco Use - Survey Data
# 4      2015           ID          Idaho  Tobacco Use - Survey Data
# ...     ...          ...            ...                        ...
# 38703  2011           MA  Massachusetts  Tobacco Use - Survey Data
# 38704  2015           KY       Kentucky  Tobacco Use - Survey Data
# 38705  1995           MO       Missouri  Tobacco Use - Survey Data
# 38706  1993           UT           Utah  Tobacco Use - Survey Data
# 38707  2001           AR       Arkansas  Tobacco Use - Survey Data
#
#                            TopicDesc     MeasureDesc  \
# 0              Cigarette Use (Youth)  Smoking Status
# ...

# %%
df2
# Out:
#        YEAR LocationAbbr   LocationDesc                  TopicType  \
# 0      2004           OH           Ohio  Tobacco Use – Survey Data
# 1      2008           AL        Alabama  Tobacco Use – Survey Data
# 2      2015           WV  West Virginia  Tobacco Use – Survey Data
# 3      2005           IL       Illinois  Tobacco Use – Survey Data
# 4      2005           CT    Connecticut  Tobacco Use – Survey Data
# ...     ...          ...            ...                        ...
# 10595  2002           KS         Kansas  Tobacco Use – Survey Data
# 10596  2015           IL       Illinois  Tobacco Use – Survey Data
# 10597  2010           WI      Wisconsin  Tobacco Use – Survey Data
# 10598  2009           LA      Louisiana  Tobacco Use – Survey Data
# 10599  2010           DE       Delaware  Tobacco Use – Survey Data
#
#                            TopicDesc  \
# 0              Cigarette Use (Youth)
# 1              Cigarette Use (Youth)
# 2      Smokeless Tobacco Use (Youth)
# ...

# %%
df1.describe()
# Out:
#                YEAR    Data_Value  Data_Value_Std_Err  Low_Confidence_Limit  \
# count  38708.000000  24275.000000        24275.000000          24275.000000
# mean    2008.833109     13.715967            1.460470             11.135267
# std        6.553405     16.349020            1.257424             14.885942
# min     1993.000000      0.000000            0.000000              0.000000
# 25%     2005.000000      2.300000            0.600000              1.200000
# 50%     2009.000000      7.500000            1.200000              5.100000
# 75%     2015.000000     18.200000            2.000000             14.400000
# max     2017.000000     95.200000           13.300000             90.500000
#
#        High_Confidence_Limit   Sample_Size  DisplayOrder
# count           24275.000000  24275.000000  38708.000000
# mean               17.332651   1695.411864      1.717629
# std                17.745373   3069.954989      0.712968
# ...

# %%
df1.describe(include='O') # '0'  stands for object
# Out:
#        LocationAbbr  LocationDesc                  TopicType  \
# count         38708         38708                      38708
# unique           51            51                          1
# top              ND  North Dakota  Tobacco Use - Survey Data
# freq           1440          1440                      38708
#
#                     TopicDesc     MeasureDesc                 SubMeasure  \
# count                   38708           38708                      38708
# unique                      5               2                         11
# top     Cigarette Use (Youth)  Smoking Status  Frequent Cigarette Smoker
# freq                    16270           24778                       5678
#
#        DataSource Response Data_Value_Unit Data_Value_Type  ...    Education  \
# count       38708    38708           38708           38708  ...        38708
# unique          1        3               1               1  ...            2
# ...

# %%
df1.info() #see a summary of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38708 entries, 0 to 38707
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YEAR                        38708 non-null  int64
#  1   LocationAbbr                38708 non-null  object
#  2   LocationDesc                38708 non-null  object
#  3   TopicType                   38708 non-null  object
#  4   TopicDesc                   38708 non-null  object
#  5   MeasureDesc                 38708 non-null  object
#  6   SubMeasure                  38708 non-null  object
#  7   DataSource                  38708 non-null  object
#  8   Response                    38708 non-null  object
#  9   Data_Value_Unit             38708 non-null  object
#  10  Data_Value_Type             38708 non-null  object
#  11  Data_Value                  24275 non-null  float64
#  12  Data_Value_Footnote_Symbol  14433 non-null  object
# ...

# %%
df1.columns
# Out:
# Index(['YEAR', 'LocationAbbr', 'LocationDesc', 'TopicType', 'TopicDesc',
#        'MeasureDesc', 'SubMeasure', 'DataSource', 'Response',
#        'Data_Value_Unit', 'Data_Value_Type', 'Data_Value',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Data_Value_Std_Err', 'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'Sample_Size', 'Gender', 'Age', 'Race', 'Education', 'GeoLocation',
#        'TopicTypeId', 'TopicId', 'MeasureId', 'StratificationID1',
#        'StratificationID2', 'StratificationID3', 'StratificationID4',
#        'SubMeasureID', 'DisplayOrder'],
#       dtype='object')

# %%
df1 = df1.drop('LocationAbbr', axis=1)

# %%
df1.head() #print the first several rows of the data
# Out:
#    YEAR   LocationDesc                  TopicType  \
# 0  1999  Massachusetts  Tobacco Use - Survey Data
# 1  2005           Ohio  Tobacco Use - Survey Data
# 2  1997           Iowa  Tobacco Use - Survey Data
# 3  2007      Louisiana  Tobacco Use - Survey Data
# 4  2015          Idaho  Tobacco Use - Survey Data
#
#                        TopicDesc     MeasureDesc  \
# 0          Cigarette Use (Youth)  Smoking Status
# 1          Cigarette Use (Youth)  Smoking Status
# 2  Smokeless Tobacco Use (Youth)     User Status
# 3              Cigar Use (Youth)  Smoking Status
# 4              Cigar Use (Youth)  Smoking Status
#
#                        SubMeasure DataSource  Response Data_Value_Unit  \
# 0       Frequent Cigarette Smoker      YRBSS  Frequent               %
# 1        Current Cigarette Smoker      YRBSS   Current               %
# 2  Current Smokeless Tobacco User      YRBSS   Current               %
# 3           Frequent Cigar Smoker      YRBSS  Frequent               %
# ...

# %%
df1=df1.set_index('YEAR')

# %%
df1.Data_Value.sort_values(ascending=False).head()
# Out:
# YEAR
# 1995    95.2
# 1997    92.0
# 1995    90.7
# 1999    89.5
# 1995    88.5
# Name: Data_Value, dtype: float64

# %%
df1.Data_Value_Unit.value_counts()
# Out:
# %    38708
# Name: Data_Value_Unit, dtype: int64

# %%
df1.drop(columns=['DataSource', 'TopicTypeId', 'Data_Value_Type'], inplace=True)

# %%
df1.head()
# Out:
#        LocationDesc                  TopicType                      TopicDesc  \
# YEAR
# 1999  Massachusetts  Tobacco Use - Survey Data          Cigarette Use (Youth)
# 2005           Ohio  Tobacco Use - Survey Data          Cigarette Use (Youth)
# 1997           Iowa  Tobacco Use - Survey Data  Smokeless Tobacco Use (Youth)
# 2007      Louisiana  Tobacco Use - Survey Data              Cigar Use (Youth)
# 2015          Idaho  Tobacco Use - Survey Data              Cigar Use (Youth)
#
#          MeasureDesc                      SubMeasure  Response  \
# YEAR
# 1999  Smoking Status       Frequent Cigarette Smoker  Frequent
# 2005  Smoking Status        Current Cigarette Smoker   Current
# 1997     User Status  Current Smokeless Tobacco User   Current
# 2007  Smoking Status           Frequent Cigar Smoker  Frequent
# 2015  Smoking Status            Current Cigar Smoker   Current
#
#      Data_Value_Unit  Data_Value Data_Value_Footnote_Symbol  \
# YEAR
# ...

# %%
df1.TopicType.unique()
# Out:
# array(['Tobacco Use - Survey Data'], dtype=object)

# %%
#df1['New_Data_Value']=df1['Data_Value'] + df1['Data_Value_Unit']

# %%
df1[['Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'Data_Value_Std_Err', 'Low_Confidence_Limit','High_Confidence_Limit', 'Sample_Size']].head(50)
# Out:
#      Data_Value_Footnote_Symbol  \
# YEAR
# 1999                        NaN
# 2005                        NaN
# 1997                        NaN
# 2007                          *
# 2015                          *
# 2009                          *
# 2011                        NaN
# 2007                          *
# 2015                        NaN
# 2007                          *
# 2015                        NaN
# 2015                        NaN
# 2017                        NaN
# 2009                        NaN
# 2017                        NaN
# 2015                        NaN
# 2017                        NaN
# 1997                        NaN
# 2013                        NaN
# 2017                        NaN
# 2017                        NaN
# 2017                        NaN
# 2017                        NaN
# 2009                        NaN
# 2017                        NaN
# 2017                        NaN
# 2017                        NaN
# 2017                        NaN
# ...

# %%
df1['Data_Value_Footnote_Symbol'].unique()
# Out:
# array([nan, '*'], dtype=object)

# %%
df1['Data_Value_Footnote'].unique()
# Out:
# array([nan,
#        'Data in these cells have been suppressed because of a small sample size'],
#       dtype=object)

# %%
df1.drop(columns=['Data_Value_Footnote_Symbol','Data_Value_Footnote'], inplace=True)

# %%
df1.head()
# Out:
#        LocationDesc                  TopicType                      TopicDesc  \
# YEAR
# 1999  Massachusetts  Tobacco Use - Survey Data          Cigarette Use (Youth)
# 2005           Ohio  Tobacco Use - Survey Data          Cigarette Use (Youth)
# 1997           Iowa  Tobacco Use - Survey Data  Smokeless Tobacco Use (Youth)
# 2007      Louisiana  Tobacco Use - Survey Data              Cigar Use (Youth)
# 2015          Idaho  Tobacco Use - Survey Data              Cigar Use (Youth)
#
#          MeasureDesc                      SubMeasure  Response  \
# YEAR
# 1999  Smoking Status       Frequent Cigarette Smoker  Frequent
# 2005  Smoking Status        Current Cigarette Smoker   Current
# 1997     User Status  Current Smokeless Tobacco User   Current
# 2007  Smoking Status           Frequent Cigar Smoker  Frequent
# 2015  Smoking Status            Current Cigar Smoker   Current
#
#      Data_Value_Unit  Data_Value  Data_Value_Std_Err  Low_Confidence_Limit  \
# YEAR
# ...

# %%
df1['StratificationID1'].unique()
# Out:
# array(['1GEN', '2GEN', '3GEN'], dtype=object)

# %%
df1['StratificationID2'].unique()
# Out:
# array(['8AGE'], dtype=object)

# %%
df1['StratificationID3'].unique()
# Out:
# array(['7RAC', '1RAC', '6RAC', '2RAC', '8RAC', '5RAC', '4RAC', '9RAC'],
#       dtype=object)

# %%
df1['StratificationID4'].unique()
# Out:
# array(['2EDU', '1EDU'], dtype=object)

# %%
df1['SubMeasureID'].unique()
# Out:
# array(['YRB02', 'YRB01', 'YRB04', 'YRB10', 'YRB09', 'YRB05', 'YRB03',
#        'YRB06', 'YRB08', 'YRB12', 'YRB07'], dtype=object)

# %%
df1.drop(columns=['StratificationID1','StratificationID2','StratificationID3','StratificationID4','SubMeasureID'], inplace=True)

# %%
df1.head()
# Out:
#        LocationDesc                  TopicType                      TopicDesc  \
# YEAR
# 1999  Massachusetts  Tobacco Use - Survey Data          Cigarette Use (Youth)
# 2005           Ohio  Tobacco Use - Survey Data          Cigarette Use (Youth)
# 1997           Iowa  Tobacco Use - Survey Data  Smokeless Tobacco Use (Youth)
# 2007      Louisiana  Tobacco Use - Survey Data              Cigar Use (Youth)
# 2015          Idaho  Tobacco Use - Survey Data              Cigar Use (Youth)
#
#          MeasureDesc                      SubMeasure  Response  \
# YEAR
# 1999  Smoking Status       Frequent Cigarette Smoker  Frequent
# 2005  Smoking Status        Current Cigarette Smoker   Current
# 1997     User Status  Current Smokeless Tobacco User   Current
# 2007  Smoking Status           Frequent Cigar Smoker  Frequent
# 2015  Smoking Status            Current Cigar Smoker   Current
#
#      Data_Value_Unit  Data_Value  Data_Value_Std_Err  Low_Confidence_Limit  \
# YEAR
# ...

# %%
df1[df1.isnull().any(axis=1)]  #check the missing values
# Out:
#        LocationDesc                  TopicType                      TopicDesc  \
# YEAR
# 2007      Louisiana  Tobacco Use - Survey Data              Cigar Use (Youth)
# 2015          Idaho  Tobacco Use - Survey Data              Cigar Use (Youth)
# 2009       Maryland  Tobacco Use - Survey Data              Cigar Use (Youth)
# 2007  New Hampshire  Tobacco Use - Survey Data          Cigarette Use (Youth)
# 2007        Indiana  Tobacco Use - Survey Data  Smokeless Tobacco Use (Youth)
# ...             ...                        ...                            ...
# 2009    Mississippi  Tobacco Use - Survey Data          Cigarette Use (Youth)
# 2009    Mississippi  Tobacco Use - Survey Data              Cigar Use (Youth)
# 2005  West Virginia  Tobacco Use - Survey Data          Cigarette Use (Youth)
# 2001        Vermont  Tobacco Use - Survey Data              Cigar Use (Youth)
# 2015       Kentucky  Tobacco Use - Survey Data  Smokeless Tobacco Use (Youth)
#
# ...

# %%
df1['Data_Value_Std_Err'].unique()
# Out:
# array([ 4.4,  2.9,  2.2,  nan,  0.2,  3.9,  1.1,  3. ,  2.1,  0.7,  2.3,
#         0.1,  0. ,  1.2,  1. ,  2.4,  0.9,  4.5,  4.3,  0.6,  0.4,  1.3,
#         0.8,  1.7,  1.6,  1.4,  0.3,  2.7,  1.5,  3.7,  3.4,  0.5,  1.9,
#         2.8,  1.8,  3.2,  2. ,  2.6,  3.1,  2.5,  3.5,  6.2,  4.6,  5.2,
#         5.6,  4.1,  9.4,  4.9,  4. ,  3.6,  5.4,  4.2,  4.7,  5.3,  4.8,
#         5.5,  6.1,  7.7,  3.8,  3.3,  6.4,  5.8,  5.1,  7. , 11.9,  9.7,
#         8.4,  7.1,  5. ,  7.6, 11.1, 11. ,  6. ,  6.5,  8.7,  6.7, 10.5,
#         6.3, 11.8,  7.5, 12. , 11.5,  7.3,  9.5,  9.8,  8.9,  8.8,  6.9,
#        11.7,  8.6,  6.6,  5.7,  7.2,  5.9,  7.8,  6.8, 10.2, 10. , 10.8,
#        12.6, 10.3,  7.4,  7.9, 12.2,  8.5,  8. , 10.4,  9.6, 12.5,  8.1,
#        11.6, 11.2,  9.9,  9.2,  9.3,  9. , 13.3, 10.1, 12.8,  8.2])

# %%
df1['Low_Confidence_Limit'].unique()
# Out:
# array([13.3,  7.1, 18.2,  nan,  0. , 23.9, 12. ,  7.6,  5.5,  0.4, 35.2,
#        13.4,  1. ,  1.4,  0.1, 36.7, 13.8, 36. , 31.2,  1.2,  1.3,  0.6,
#         8.3,  6.4, 25.5,  5.3,  0.7,  0.3,  9.7,  6.8, 19.8,  1.9,  4.6,
#         5.2, 17. ,  4.8, 16. ,  8.6,  2.1, 30.9, 36.5,  4.2,  3.1, 41.7,
#         3.6,  1.7, 23.5,  4.9,  7.8,  3.7, 20.1, 20. ,  2.4, 62.3,  2.5,
#         9.2, 11.2,  2. , 38.7, 32.7, 11.7,  9.3,  2.6, 11.3,  0.8,  1.1,
#         0.2,  7. ,  6.5,  7.3, 37.4, 48.4,  0.9, 26.8, 36.2,  0.5, 14.3,
#         5.8,  2.7, 21.9, 32.1,  5.7,  9.5, 30.6, 38.3,  7.5,  7.9,  6.3,
#         3.5,  2.9, 16.1,  1.8, 15.2, 22.6, 39.1,  7.4, 35.6, 34.2,  1.5,
#        37.1,  2.8, 11.9, 14.6, 10.9,  9. , 22.1, 18.7,  5.4, 15.9, 17.1,
#        17.6,  4.5, 14.8, 32.6, 28.2, 21.7,  4.7,  5.9, 27.2, 31.6,  4.3,
#        19.5, 17.3,  6.7,  2.3, 12.7, 10.6, 41.6, 13.2, 26. , 20.4,  8.1,
#        18.5,  5. ,  6.1, 13. ,  2.2, 32.3,  3. ,  8. , 39.5, 14. , 13.7,
# ...

# %%
df1['Sample_Size'].unique()
# Out:
# array([  116.,   230.,   756., ..., 27455.,  5239.,  1415.])

# %%
df1['High_Confidence_Limit'].unique()
# Out:
# array([31.3, 19.1, 27.4,  nan,  1. , 40.8, 16.6, 19.9, 13.7,  3.9, 45. ,
#         0.7,  0.5, 29.7,  0.2,  4.3,  6.6, 10.4, 46.5, 18.8,  0.3, 39.7,
#        49.3,  1.5,  1.4,  1.6, 26.3,  4.2,  7.8, 30.6, 15.3,  0. ,  4.4,
#         4.9, 19. , 11.9, 28.8,  2.6,  6.1,  9.8,  9.5, 12.3, 21. ,  8.6,
#        14.8,  7.5,  2.1,  9.2, 27.2, 12.9,  8.4, 45.9, 50.7, 10.3,  8. ,
#         1.1, 51.2,  9. ,  3.8, 10.5,  2.2, 30.4,  5.5,  8.9, 19.4, 23.3,
#        31.9,  2.9,  5.9, 69.4,  5.3,  5.1,  4.5, 26.2, 18. ,  3.2, 11.1,
#         3.6, 43.8,  3.3,  1.2, 39.2, 17.3, 11. , 14.1, 17.9,  2.4,  7.1,
#         9.3, 11.2, 11.3,  6.8, 61. ,  5.6, 31.8, 43.3,  6.5,  0.6,  1.8,
#         4.8,  9.7,  7.9, 18.5, 10. , 29.1, 40.2, 17.7, 15.9, 11.4, 43.2,
#        50.2, 14.4, 13.9,  3.4, 22.4,  3. ,  8.1, 26. , 33. ,  1.3,  2.8,
#        44.5,  8.7, 20.2,  0.8, 46.7, 48.2,  4. , 45.2,  2.3, 15.7, 15.6,
#        33.9, 28.3, 23.9,  8.3, 19.2, 24.9, 25.3,  8.2, 20.1, 25.8,  4.7,
# ...

# %%
df1=df1[['High_Confidence_Limit','Data_Value','Sample_Size','Low_Confidence_Limit','Data_Value_Std_Err']].fillna(df1[['High_Confidence_Limit','Data_Value','Sample_Size','Low_Confidence_Limit','Data_Value_Std_Err']].mean())

# %%
df1[df1.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [High_Confidence_Limit, Data_Value, Sample_Size, Low_Confidence_Limit, Data_Value_Std_Err]
# Index: []

# %%
df1['Data_Value']
# Out:
# YEAR
# 1999    20.900000
# 2005    11.800000
# 1997    22.400000
# 2007    13.715967
# 2015    13.715967
#           ...
# 2011     7.200000
# 2015    13.715967
# 1995     5.100000
# 1993     7.600000
# 2001    76.700000
# Name: Data_Value, Length: 38708, dtype: float64

# %%
df1.groupby('YEAR')['Data_Value'].sum()
# Out:
# YEAR
# 1993    15263.914476
# 1995    23301.128128
# 1997    27126.197920
# 1999    27504.676931
# 2001    31770.023263
# 2003    38295.381442
# 2005    42695.244486
# 2007    47808.917730
# 2009    47943.795015
# 2011    48844.980774
# 2013    45431.734521
# 2015    71764.269162
# 2017    63167.388503
# Name: Data_Value, dtype: float64

# %%
df2.describe()
# Out:
#                YEAR    Data_Value  Data_Value_Std_Err  Low_Confidence_Limit  \
# count  10600.000000  10080.000000        10080.000000          10083.000000
# mean    2007.053491     20.336806            1.851429             16.715253
# std        5.462656     21.168271            1.777441             18.575128
# min     1999.000000      0.000000            0.000000              0.000000
# 25%     2002.000000      3.000000            0.600000              1.700000
# 50%     2006.000000     10.550000            1.300000              7.900000
# 75%     2011.000000     36.425000            2.400000             29.600000
# max     2017.000000     98.000000           16.100000             97.600000
#
#        High_Confidence_Limit   Sample_Size  DisplayOrder
# count           10080.000000  10080.000000  10600.000000
# mean               23.961806   1483.412897      8.106887
# std                23.981915   2189.565233      3.076806
# ...

# %%
df2.describe(include='O') # '0'  stands for object
# Out:
#        LocationAbbr LocationDesc                  TopicType  \
# count         10600        10600                      10600
# unique           50           50                          1
# top              MS  Mississippi  Tobacco Use – Survey Data
# freq            651          651                      10600
#
#                     TopicDesc     MeasureDesc DataSource Response  \
# count                   10600           10600      10600     8190
# unique                      3               4          2        3
# top     Cigarette Use (Youth)  Smoking Status        YTS     Ever
# freq                     4107            4107      10566     2730
#
#        Data_Value_Unit Data_Value_Type Data_Value_Footnote_Symbol  ...  \
# count            10600           10600                        517  ...
# unique               1               1                          1  ...
# top                  %      Percentage                          *  ...
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10600 entries, 0 to 10599
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YEAR                        10600 non-null  int64
#  1   LocationAbbr                10600 non-null  object
#  2   LocationDesc                10600 non-null  object
#  3   TopicType                   10600 non-null  object
#  4   TopicDesc                   10600 non-null  object
#  5   MeasureDesc                 10600 non-null  object
#  6   DataSource                  10600 non-null  object
#  7   Response                    8190 non-null   object
#  8   Data_Value_Unit             10600 non-null  object
#  9   Data_Value_Type             10600 non-null  object
#  10  Data_Value                  10080 non-null  float64
#  11  Data_Value_Footnote_Symbol  517 non-null    object
#  12  Data_Value_Footnote         517 non-null    object
# ...

# %%
df2.columns
# Out:
# Index(['YEAR', 'LocationAbbr', 'LocationDesc', 'TopicType', 'TopicDesc',
#        'MeasureDesc', 'DataSource', 'Response', 'Data_Value_Unit',
#        'Data_Value_Type', 'Data_Value', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Data_Value_Std_Err', 'Low_Confidence_Limit',
#        'High_Confidence_Limit', 'Sample_Size', 'Gender', 'Race', 'Age',
#        'Education', 'GeoLocation', 'TopicTypeId', 'TopicId', 'MeasureId',
#        'StratificationID1', 'StratificationID2', 'StratificationID3',
#        'StratificationID4', 'SubMeasureID', 'DisplayOrder'],
#       dtype='object')

# %%
df2 = df2.drop('LocationAbbr', axis=1)

# %%
df2.head()
# Out:
#    YEAR   LocationDesc                  TopicType  \
# 0  2004           Ohio  Tobacco Use – Survey Data
# 1  2008        Alabama  Tobacco Use – Survey Data
# 2  2015  West Virginia  Tobacco Use – Survey Data
# 3  2005       Illinois  Tobacco Use – Survey Data
# 4  2005    Connecticut  Tobacco Use – Survey Data
#
#                        TopicDesc     MeasureDesc DataSource  Response  \
# 0          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 1          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 2  Smokeless Tobacco Use (Youth)     User Status        YTS  Frequent
# 3          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 4  Smokeless Tobacco Use (Youth)     User Status        YTS      Ever
#
#   Data_Value_Unit Data_Value_Type  Data_Value  ...  \
# 0               %      Percentage        32.2  ...
# 1               %      Percentage        47.8  ...
# 2               %      Percentage        12.7  ...
# ...

# %%
df2=df2.set_index('YEAR')

# %%
df2.Data_Value.sort_values(ascending=False).head()
# Out:
# YEAR
# 2002    98.0
# 2002    97.9
# 2002    97.9
# 2002    96.2
# 2002    96.1
# Name: Data_Value, dtype: float64

# %%
df2.Data_Value_Unit.value_counts()
# Out:
# %    10600
# Name: Data_Value_Unit, dtype: int64

# %%
df2.drop(columns=['DataSource', 'TopicTypeId', 'Data_Value_Type','Response'], inplace=True)
df2.head()
# Out:
#        LocationDesc                  TopicType                      TopicDesc  \
# YEAR
# 2004           Ohio  Tobacco Use – Survey Data          Cigarette Use (Youth)
# 2008        Alabama  Tobacco Use – Survey Data          Cigarette Use (Youth)
# 2015  West Virginia  Tobacco Use – Survey Data  Smokeless Tobacco Use (Youth)
# 2005       Illinois  Tobacco Use – Survey Data          Cigarette Use (Youth)
# 2005    Connecticut  Tobacco Use – Survey Data  Smokeless Tobacco Use (Youth)
#
#          MeasureDesc Data_Value_Unit  Data_Value Data_Value_Footnote_Symbol  \
# YEAR
# 2004  Smoking Status               %        32.2                        NaN
# 2008  Smoking Status               %        47.8                        NaN
# 2015     User Status               %        12.7                        NaN
# 2005  Smoking Status               %        28.5                        NaN
# 2005     User Status               %        20.5                        NaN
#
# ...

# %%
df2.drop(columns=['Data_Value_Footnote_Symbol','Data_Value_Footnote','TopicId', 'MeasureId',
       'StratificationID1', 'StratificationID2', 'StratificationID3',
       'StratificationID4', 'SubMeasureID'], inplace=True)

# %%
df2.head()
# Out:
#        LocationDesc                  TopicType                      TopicDesc  \
# YEAR
# 2004           Ohio  Tobacco Use – Survey Data          Cigarette Use (Youth)
# 2008        Alabama  Tobacco Use – Survey Data          Cigarette Use (Youth)
# 2015  West Virginia  Tobacco Use – Survey Data  Smokeless Tobacco Use (Youth)
# 2005       Illinois  Tobacco Use – Survey Data          Cigarette Use (Youth)
# 2005    Connecticut  Tobacco Use – Survey Data  Smokeless Tobacco Use (Youth)
#
#          MeasureDesc Data_Value_Unit  Data_Value  Data_Value_Std_Err  \
# YEAR
# 2004  Smoking Status               %        32.2                 3.2
# 2008  Smoking Status               %        47.8                 2.9
# 2015     User Status               %        12.7                 1.9
# 2005  Smoking Status               %        28.5                 2.2
# 2005     User Status               %        20.5                 2.3
#
# ...

# %%
df2[df2.isnull().any(axis=1)]
# Out:
#       LocationDesc                  TopicType          TopicDesc  \
# YEAR
# 2008     Minnesota  Tobacco Use – Survey Data  Cessation (Youth)
# 2003          Utah  Tobacco Use – Survey Data  Cessation (Youth)
# 2004     Wisconsin  Tobacco Use – Survey Data  Cessation (Youth)
# 2016     Wisconsin  Tobacco Use – Survey Data  Cessation (Youth)
# 2014     Minnesota  Tobacco Use – Survey Data  Cessation (Youth)
# ...            ...                        ...                ...
# 2009   Mississippi  Tobacco Use – Survey Data  Cessation (Youth)
# 2015   Connecticut  Tobacco Use – Survey Data  Cessation (Youth)
# 2003     Wisconsin  Tobacco Use – Survey Data  Cessation (Youth)
# 2008  Pennsylvania  Tobacco Use – Survey Data  Cessation (Youth)
# 2010     Wisconsin  Tobacco Use – Survey Data  Cessation (Youth)
#
#                                             MeasureDesc Data_Value_Unit  \
# YEAR
# 2008        Percent of Current Smokers Who Want to Quit               %
# ...

# %%
df2=df2[['High_Confidence_Limit','Data_Value','Sample_Size','Low_Confidence_Limit','Data_Value_Std_Err']].fillna(df2[['High_Confidence_Limit','Data_Value','Sample_Size','Low_Confidence_Limit','Data_Value_Std_Err']].mean())

# %%
df2[df2.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [High_Confidence_Limit, Data_Value, Sample_Size, Low_Confidence_Limit, Data_Value_Std_Err]
# Index: []

# %%
df2.groupby('YEAR')['Data_Value'].sum()
# Out:
# YEAR
# 1999     9699.100000
# 2000    32558.409722
# 2001     9937.420833
# 2002    25504.099306
# 2003    10578.978472
# 2004    12639.204167
# 2005    13829.272917
# 2006    11248.925694
# 2007    10333.909722
# 2008     8852.209722
# 2009    12589.277778
# 2010     8004.209722
# 2011     9315.483333
# 2012     3889.872917
# 2013    11625.887500
# 2014     5390.014583
# 2015     9094.465972
# 2016     3590.872222
# 2017     6888.524306
# Name: Data_Value, dtype: float64

# %%
df1.head()
# Out:
#       High_Confidence_Limit  Data_Value  Sample_Size  Low_Confidence_Limit  \
# YEAR
# 1999              31.300000   20.900000   116.000000             13.300000
# 2005              19.100000   11.800000   230.000000              7.100000
# 1997              27.400000   22.400000   756.000000             18.200000
# 2007              17.332651   13.715967  1695.411864             11.135267
# 2015              17.332651   13.715967  1695.411864             11.135267
#
#       Data_Value_Std_Err
# YEAR
# 1999             4.40000
# 2005             2.90000
# 1997             2.20000
# 2007             1.46047
# 2015             1.46047

# %%
df2.head()
# Out:
#       High_Confidence_Limit  Data_Value  Sample_Size  Low_Confidence_Limit  \
# YEAR
# 2004                   38.5        32.2       1377.0                  25.8
# 2008                   53.5        47.8        654.0                  42.1
# 2015                   16.4        12.7        781.0                   9.0
# 2005                   32.8        28.5       1323.0                  24.2
# 2005                   25.1        20.5        973.0                  16.0
#
#       Data_Value_Std_Err
# YEAR
# 2004                 3.2
# 2008                 2.9
# 2015                 1.9
# 2005                 2.2
# 2005                 2.3

# %%
df=df1.merge(df2, on='YEAR',how = 'left')
df.head()
# Out:
#       High_Confidence_Limit_x  Data_Value_x  Sample_Size_x  \
# YEAR
# 1999                     31.3          20.9          116.0
# 1999                     31.3          20.9          116.0
# 1999                     31.3          20.9          116.0
# 1999                     31.3          20.9          116.0
# 1999                     31.3          20.9          116.0
#
#       Low_Confidence_Limit_x  Data_Value_Std_Err_x  High_Confidence_Limit_y  \
# YEAR
# 1999                    13.3                   4.4                      3.9
# 1999                    13.3                   4.4                      2.9
# 1999                    13.3                   4.4                     61.6
# 1999                    13.3                   4.4                     46.7
# 1999                    13.3                   4.4                      3.3
#
#       Data_Value_y  Sample_Size_y  Low_Confidence_Limit_y  \
# YEAR
# 1999           2.8         1029.0                     1.7
# ...

# %%
df.groupby('YEAR')[['Data_Value_x','Data_Value_y']].sum()
# Out:
#       Data_Value_x  Data_Value_y
# YEAR
# 1993  1.526391e+04  0.000000e+00
# 1995  2.330113e+04  0.000000e+00
# 1997  2.712620e+04  0.000000e+00
# 1999  1.023174e+07  1.520819e+07
# 2001  1.353403e+07  2.045121e+07
# 2003  1.907110e+07  2.769577e+07
# 2005  2.715418e+07  4.010489e+07
# 2007  2.466940e+07  3.616868e+07
# 2009  3.288944e+07  4.660551e+07
# 2011  2.544823e+07  3.703836e+07
# 2013  3.112074e+07  4.841020e+07
# 2015  4.140798e+07  4.941933e+07
# 2017  3.436306e+07  3.892016e+07
