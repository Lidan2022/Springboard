# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import data
df1= pd.read_csv('Youth_Risk_Behavioral_Surveillance_System__YRBSS__Data.csv')
df2= pd.read_csv('Youth_Tobacco_Survey__YTS__Data (1).csv')

# %%
df1.head() # check the first 5 lines of data
# Out:
#    YEAR LocationAbbr   LocationDesc                  TopicType  \
# 0  1999           MA  Massachusetts  Tobacco Use - Survey Data
# 1  2005           OH           Ohio  Tobacco Use - Survey Data
# 2  1997           IA           Iowa  Tobacco Use - Survey Data
# 3  2007           LA      Louisiana  Tobacco Use - Survey Data
# 4  2015           ID          Idaho  Tobacco Use - Survey Data
#
#                        TopicDesc     MeasureDesc  \
# 0          Cigarette Use (Youth)  Smoking Status
# 1          Cigarette Use (Youth)  Smoking Status
# 2  Smokeless Tobacco Use (Youth)     User Status
# 3              Cigar Use (Youth)  Smoking Status
# 4              Cigar Use (Youth)  Smoking Status
#
#                        SubMeasure DataSource  Response Data_Value_Unit  ...  \
# 0       Frequent Cigarette Smoker      YRBSS  Frequent               %  ...
# 1        Current Cigarette Smoker      YRBSS   Current               %  ...
# ...

# %%
df2.head()
# Out:
#    YEAR LocationAbbr   LocationDesc                  TopicType  \
# 0  2004           OH           Ohio  Tobacco Use – Survey Data
# 1  2008           AL        Alabama  Tobacco Use – Survey Data
# 2  2015           WV  West Virginia  Tobacco Use – Survey Data
# 3  2005           IL       Illinois  Tobacco Use – Survey Data
# 4  2005           CT    Connecticut  Tobacco Use – Survey Data
#
#                        TopicDesc     MeasureDesc DataSource  Response  \
# 0          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 1          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 2  Smokeless Tobacco Use (Youth)     User Status        YTS  Frequent
# 3          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 4  Smokeless Tobacco Use (Youth)     User Status        YTS      Ever
#
#   Data_Value_Unit Data_Value_Type  ...                    GeoLocation  \
# 0               %      Percentage  ...  (40.060210141, -82.404260056)
# ...

# %%
df1.columns
# Out:
# Index(['YEAR', 'LocationAbbr', 'LocationDesc', 'TopicType', 'TopicDesc',
#        'MeasureDesc', 'SubMeasure', 'DataSource', 'Response',
#        'Data_Value_Unit', 'Data_Value_Type', 'Data_Value',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Data_Value_Std_Err', 'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'Sample_Size', 'Gender', 'Age', 'Race', 'Education', 'GeoLocation',
#        'TopicTypeId', 'TopicId', 'MeasureId', 'StratificationID1',
#        'StratificationID2', 'StratificationID3', 'StratificationID4',
#        'SubMeasureID', 'DisplayOrder'],
#       dtype='object')

# %%
df1.drop(columns=['LocationAbbr','DataSource','Data_Value_Footnote','TopicId','MeasureId','StratificationID1','StratificationID2','StratificationID3','StratificationID4','SubMeasureID','DisplayOrder'], inplace=True)

# %%
df1.head()
# Out:
#    YEAR   LocationDesc                  TopicType  \
# 0  1999  Massachusetts  Tobacco Use - Survey Data
# 1  2005           Ohio  Tobacco Use - Survey Data
# 2  1997           Iowa  Tobacco Use - Survey Data
# 3  2007      Louisiana  Tobacco Use - Survey Data
# 4  2015          Idaho  Tobacco Use - Survey Data
#
#                        TopicDesc     MeasureDesc  \
# 0          Cigarette Use (Youth)  Smoking Status
# 1          Cigarette Use (Youth)  Smoking Status
# 2  Smokeless Tobacco Use (Youth)     User Status
# 3              Cigar Use (Youth)  Smoking Status
# 4              Cigar Use (Youth)  Smoking Status
#
#                        SubMeasure  Response Data_Value_Unit Data_Value_Type  \
# 0       Frequent Cigarette Smoker  Frequent               %      Percentage
# 1        Current Cigarette Smoker   Current               %      Percentage
# 2  Current Smokeless Tobacco User   Current               %      Percentage
# ...

# %%
df1['Data_Value_Footnote_Symbol'].unique()
# Out:
# array([nan, '*'], dtype=object)

# %%
df1 = df1.drop('Data_Value_Footnote_Symbol', axis=1)
df1.head()
# Out:
#    YEAR   LocationDesc                  TopicType  \
# 0  1999  Massachusetts  Tobacco Use - Survey Data
# 1  2005           Ohio  Tobacco Use - Survey Data
# 2  1997           Iowa  Tobacco Use - Survey Data
# 3  2007      Louisiana  Tobacco Use - Survey Data
# 4  2015          Idaho  Tobacco Use - Survey Data
#
#                        TopicDesc     MeasureDesc  \
# 0          Cigarette Use (Youth)  Smoking Status
# 1          Cigarette Use (Youth)  Smoking Status
# 2  Smokeless Tobacco Use (Youth)     User Status
# 3              Cigar Use (Youth)  Smoking Status
# 4              Cigar Use (Youth)  Smoking Status
#
#                        SubMeasure  Response Data_Value_Unit Data_Value_Type  \
# 0       Frequent Cigarette Smoker  Frequent               %      Percentage
# 1        Current Cigarette Smoker   Current               %      Percentage
# 2  Current Smokeless Tobacco User   Current               %      Percentage
# ...

# %%
df1['TopicType'].unique()
# Out:
# array(['Tobacco Use - Survey Data'], dtype=object)

# %%
df1['TopicDesc'].unique()
# Out:
# array(['Cigarette Use (Youth)', 'Smokeless Tobacco Use (Youth)',
#        'Cigar Use (Youth)', 'E-Cigarette Use (Youth)',
#        'Any Tobacco Use (Youth)'], dtype=object)

# %%
df1['MeasureDesc'].unique()
# Out:
# array(['Smoking Status', 'User Status'], dtype=object)

# %%
df1.drop(columns=['TopicType', 'Data_Value_Type', 'TopicTypeId', 'MeasureDesc'], inplace=True)
df1.head()
# Out:
#    YEAR   LocationDesc                      TopicDesc  \
# 0  1999  Massachusetts          Cigarette Use (Youth)
# 1  2005           Ohio          Cigarette Use (Youth)
# 2  1997           Iowa  Smokeless Tobacco Use (Youth)
# 3  2007      Louisiana              Cigar Use (Youth)
# 4  2015          Idaho              Cigar Use (Youth)
#
#                        SubMeasure  Response Data_Value_Unit  Data_Value  \
# 0       Frequent Cigarette Smoker  Frequent               %        20.9
# 1        Current Cigarette Smoker   Current               %        11.8
# 2  Current Smokeless Tobacco User   Current               %        22.4
# 3           Frequent Cigar Smoker  Frequent               %         NaN
# 4            Current Cigar Smoker   Current               %         NaN
#
#    Data_Value_Std_Err  Low_Confidence_Limit  High_Confidence_Limit  \
# 0                 4.4                  13.3                   31.3
# 1                 2.9                   7.1                   19.1
# ...

# %%
df1['Age'].unique()
# Out:
# array(['All Ages'], dtype=object)

# %%
df1['Race'].unique()
# Out:
# array(['Multiple Race', 'African American', 'All Races',
#        'American Indian/Alaska Native', 'Asian', 'White', 'Hispanic',
#        'Pacific Islander'], dtype=object)

# %%
df1['LocationDesc'].unique()
# Out:
# array(['Massachusetts', 'Ohio', 'Iowa', 'Louisiana', 'Idaho', 'Maryland',
#        'Hawaii', 'New Hampshire', 'Rhode Island', 'Indiana', 'Tennessee',
#        'Arkansas', 'District of Columbia', 'Maine', 'North Dakota',
#        'Virginia', 'Colorado', 'Kentucky', 'Montana', 'Illinois',
#        'New Mexico', 'Oklahoma', 'West Virginia', 'Pennsylvania',
#        'Alaska', 'Florida', 'California', 'Texas', 'Utah', 'Puerto Rico',
#        'Vermont', 'Nevada', 'Wisconsin', 'Delaware', 'Guam', 'Michigan',
#        'Arizona', 'New York', 'National (States and DC)', 'Nebraska',
#        'North Carolina', 'Kansas', 'Connecticut', 'Missouri',
#        'South Carolina', 'Georgia', 'Mississippi', 'Alabama', 'Wyoming',
#        'New Jersey', 'South Dakota'], dtype=object)

# %%
df1['YEAR'].unique()
# Out:
# array([1999, 2005, 1997, 2007, 2015, 2009, 2011, 2017, 2013, 2003, 1995,
#        1993, 2001])

# %%
df1['SubMeasure'].unique()
# Out:
# array(['Frequent Cigarette Smoker', 'Current Cigarette Smoker',
#        'Current Smokeless Tobacco User', 'Frequent Cigar Smoker',
#        'Current Cigar Smoker', 'Frequent Smokeless Tobacco User',
#        'Ever Cigarette Smoker', 'Current E-Cigarette User',
#        'Ever E-Cigarette User', 'Current Tobacco User',
#        'Frequent E-Cigarette User'], dtype=object)

# %%
df1['Education'].unique()
# Out:
# array(['High School', 'Middle School'], dtype=object)

# %%
df2.columns
# Out:
# Index(['YEAR', 'LocationAbbr', 'LocationDesc', 'TopicType', 'TopicDesc',
#        'MeasureDesc', 'DataSource', 'Response', 'Data_Value_Unit',
#        'Data_Value_Type', 'Data_Value', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Data_Value_Std_Err', 'Low_Confidence_Limit',
#        'High_Confidence_Limit', 'Sample_Size', 'Gender', 'Race', 'Age',
#        'Education', 'GeoLocation', 'TopicTypeId', 'TopicId', 'MeasureId',
#        'StratificationID1', 'StratificationID2', 'StratificationID3',
#        'StratificationID4', 'SubMeasureID', 'DisplayOrder'],
#       dtype='object')

# %%
df2.drop(columns=['LocationAbbr','DataSource','Data_Value_Footnote','TopicId','MeasureId','StratificationID1','StratificationID2','StratificationID3','StratificationID4','SubMeasureID','DisplayOrder'], inplace=True)
df2.head()
# Out:
#    YEAR   LocationDesc                  TopicType  \
# 0  2004           Ohio  Tobacco Use – Survey Data
# 1  2008        Alabama  Tobacco Use – Survey Data
# 2  2015  West Virginia  Tobacco Use – Survey Data
# 3  2005       Illinois  Tobacco Use – Survey Data
# 4  2005    Connecticut  Tobacco Use – Survey Data
#
#                        TopicDesc     MeasureDesc  Response Data_Value_Unit  \
# 0          Cigarette Use (Youth)  Smoking Status      Ever               %
# 1          Cigarette Use (Youth)  Smoking Status      Ever               %
# 2  Smokeless Tobacco Use (Youth)     User Status  Frequent               %
# 3          Cigarette Use (Youth)  Smoking Status      Ever               %
# 4  Smokeless Tobacco Use (Youth)     User Status      Ever               %
#
#   Data_Value_Type  Data_Value Data_Value_Footnote_Symbol  Data_Value_Std_Err  \
# 0      Percentage        32.2                        NaN                 3.2
# ...

# %%
df2['Data_Value_Footnote_Symbol'].unique()
# Out:
# array([nan, '*'], dtype=object)

# %%
df2 = df2.drop('Data_Value_Footnote_Symbol', axis=1)
df2.head()
# Out:
#    YEAR   LocationDesc                  TopicType  \
# 0  2004           Ohio  Tobacco Use – Survey Data
# 1  2008        Alabama  Tobacco Use – Survey Data
# 2  2015  West Virginia  Tobacco Use – Survey Data
# 3  2005       Illinois  Tobacco Use – Survey Data
# 4  2005    Connecticut  Tobacco Use – Survey Data
#
#                        TopicDesc     MeasureDesc  Response Data_Value_Unit  \
# 0          Cigarette Use (Youth)  Smoking Status      Ever               %
# 1          Cigarette Use (Youth)  Smoking Status      Ever               %
# 2  Smokeless Tobacco Use (Youth)     User Status  Frequent               %
# 3          Cigarette Use (Youth)  Smoking Status      Ever               %
# 4  Smokeless Tobacco Use (Youth)     User Status      Ever               %
#
#   Data_Value_Type  Data_Value  Data_Value_Std_Err  Low_Confidence_Limit  \
# 0      Percentage        32.2                 3.2                  25.8
# ...

# %%
df2['TopicType'].unique()
# Out:
# array(['Tobacco Use – Survey Data'], dtype=object)

# %%
df2['TopicDesc'].unique()
# Out:
# array(['Cigarette Use (Youth)', 'Smokeless Tobacco Use (Youth)',
#        'Cessation (Youth)'], dtype=object)

# %%
df2['MeasureDesc'].unique()
# Out:
# array(['Smoking Status', 'User Status',
#        'Quit Attempt in Past Year Among Current Cigarette Smokers',
#        'Percent of Current Smokers Who Want to Quit'], dtype=object)

# %%
df2.drop(columns=['TopicType', 'Data_Value_Type', 'TopicTypeId', 'MeasureDesc'], inplace=True)
df2.head()
# Out:
#    YEAR   LocationDesc                      TopicDesc  Response  \
# 0  2004           Ohio          Cigarette Use (Youth)      Ever
# 1  2008        Alabama          Cigarette Use (Youth)      Ever
# 2  2015  West Virginia  Smokeless Tobacco Use (Youth)  Frequent
# 3  2005       Illinois          Cigarette Use (Youth)      Ever
# 4  2005    Connecticut  Smokeless Tobacco Use (Youth)      Ever
#
#   Data_Value_Unit  Data_Value  Data_Value_Std_Err  Low_Confidence_Limit  \
# 0               %        32.2                 3.2                  25.8
# 1               %        47.8                 2.9                  42.1
# 2               %        12.7                 1.9                   9.0
# 3               %        28.5                 2.2                  24.2
# 4               %        20.5                 2.3                  16.0
#
#    High_Confidence_Limit  Sample_Size   Gender       Race       Age  \
# 0                   38.5       1377.0  Overall  All Races  All Ages
# ...

# %%
df2['Age'].unique()
# Out:
# array(['All Ages'], dtype=object)

# %%
df2['Race'].unique()
# Out:
# array(['All Races'], dtype=object)

# %%
df2['LocationDesc'].unique()
# Out:
# array(['Ohio', 'Alabama', 'West Virginia', 'Illinois', 'Connecticut',
#        'Idaho', 'Vermont', 'Pennsylvania', 'Louisiana', 'Kentucky',
#        'Utah', 'Minnesota', 'Delaware', 'New Hampshire', 'Massachusetts',
#        'Arkansas', 'Georgia', 'Iowa', 'North Carolina', 'Wisconsin',
#        'South Carolina', 'Mississippi', 'Indiana', 'North Dakota',
#        'Tennessee', 'New Jersey', 'Hawaii', 'Rhode Island', 'Arizona',
#        'Oklahoma', 'Kansas', 'Texas', 'California', 'Maryland',
#        'Missouri', 'Maine', 'Nebraska', 'Florida', 'New York', 'Virginia',
#        'Colorado', 'South Dakota', 'Michigan', 'Wyoming', 'New Mexico',
#        'District of Columbia', 'Guam', 'Virgin Islands',
#        'National (States and DC)', 'Puerto Rico'], dtype=object)

# %%
df2['YEAR'].unique()
# Out:
# array([2004, 2008, 2015, 2005, 2009, 2001, 2007, 2006, 2002, 2003, 2011,
#        2010, 2000, 2013, 2014, 2016, 2012, 1999, 2017])

# %%
df2['Education'].unique()
# Out:
# array(['Middle School', 'High School'], dtype=object)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38708 entries, 0 to 38707
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   YEAR                   38708 non-null  int64
#  1   LocationDesc           38708 non-null  object
#  2   TopicDesc              38708 non-null  object
#  3   SubMeasure             38708 non-null  object
#  4   Response               38708 non-null  object
#  5   Data_Value_Unit        38708 non-null  object
#  6   Data_Value             24275 non-null  float64
#  7   Data_Value_Std_Err     24275 non-null  float64
#  8   Low_Confidence_Limit   24275 non-null  float64
#  9   High_Confidence_Limit  24275 non-null  float64
#  10  Sample_Size            24275 non-null  float64
#  11  Gender                 38708 non-null  object
#  12  Age                    38708 non-null  object
#  13  Race                   38708 non-null  object
# ...

# %%
df1.describe()
# Out:
#                YEAR    Data_Value  Data_Value_Std_Err  Low_Confidence_Limit  \
# count  38708.000000  24275.000000        24275.000000          24275.000000
# mean    2008.833109     13.715967            1.460470             11.135267
# std        6.553405     16.349020            1.257424             14.885942
# min     1993.000000      0.000000            0.000000              0.000000
# 25%     2005.000000      2.300000            0.600000              1.200000
# 50%     2009.000000      7.500000            1.200000              5.100000
# 75%     2015.000000     18.200000            2.000000             14.400000
# max     2017.000000     95.200000           13.300000             90.500000
#
#        High_Confidence_Limit   Sample_Size
# count           24275.000000  24275.000000
# mean               17.332651   1695.411864
# std                17.745373   3069.954989
# min                 0.000000    100.000000
# 25%                 4.400000    412.000000
# ...

# %%
df1 = df1.set_index('YEAR')
df1
# Out:
#        LocationDesc                      TopicDesc  \
# YEAR
# 1999  Massachusetts          Cigarette Use (Youth)
# 2005           Ohio          Cigarette Use (Youth)
# 1997           Iowa  Smokeless Tobacco Use (Youth)
# 2007      Louisiana              Cigar Use (Youth)
# 2015          Idaho              Cigar Use (Youth)
# ...             ...                            ...
# 2011  Massachusetts          Cigarette Use (Youth)
# 2015       Kentucky  Smokeless Tobacco Use (Youth)
# 1995       Missouri  Smokeless Tobacco Use (Youth)
# 1993           Utah          Cigarette Use (Youth)
# 2001       Arkansas          Cigarette Use (Youth)
#
#                            SubMeasure  Response Data_Value_Unit  Data_Value  \
# YEAR
# 1999        Frequent Cigarette Smoker  Frequent               %        20.9
# 2005         Current Cigarette Smoker   Current               %        11.8
# 1997   Current Smokeless Tobacco User   Current               %        22.4
# ...

# %%
df1=df1[['Data_Value', 'Sample_Size', 'Race', 'Education']]
df1
# Out:
#       Data_Value  Sample_Size                           Race      Education
# YEAR
# 1999        20.9        116.0                  Multiple Race    High School
# 2005        11.8        230.0               African American    High School
# 1997        22.4        756.0                      All Races    High School
# 2007         NaN          NaN  American Indian/Alaska Native    High School
# 2015         NaN          NaN               African American    High School
# ...          ...          ...                            ...            ...
# 2011         7.2       1310.0                      All Races    High School
# 2015         NaN          NaN                          Asian  Middle School
# 1995         5.1        381.0               African American    High School
# 1993         7.6       3741.0                          White    High School
# 2001        76.7        759.0                      All Races    High School
#
# [38708 rows x 4 columns]

# %%
df1[['Race','Education']].isnull().sum()
# Out:
# Race         0
# Education    0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# Data_Value     14433
# Sample_Size    14433
# Race               0
# Education          0
# dtype: int64

# %%
df1['Data_Value'].fillna(df1['Data_Value'].mean(), inplace=True)
df1
# Out:
# /Users/wencan/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#       Data_Value  Sample_Size                           Race      Education
# YEAR
# 1999   20.900000        116.0                  Multiple Race    High School
# 2005   11.800000        230.0               African American    High School
# 1997   22.400000        756.0                      All Races    High School
# 2007   13.715967          NaN  American Indian/Alaska Native    High School
# 2015   13.715967          NaN               African American    High School
# ...          ...          ...                            ...            ...
# 2011    7.200000       1310.0                      All Races    High School
# ...

# %%
df1['Sample_Size'].fillna(method ='ffill', inplace =True)
# Out:
# /Users/wencan/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
df1
# Out:
#       Data_Value  Sample_Size                           Race      Education
# YEAR
# 1999   20.900000        116.0                  Multiple Race    High School
# 2005   11.800000        230.0               African American    High School
# 1997   22.400000        756.0                      All Races    High School
# 2007   13.715967        756.0  American Indian/Alaska Native    High School
# 2015   13.715967        756.0               African American    High School
# ...          ...          ...                            ...            ...
# 2011    7.200000       1310.0                      All Races    High School
# 2015   13.715967       1310.0                          Asian  Middle School
# 1995    5.100000        381.0               African American    High School
# 1993    7.600000       3741.0                          White    High School
# 2001   76.700000        759.0                      All Races    High School
#
# [38708 rows x 4 columns]

# %%
#df = df1.groupby('YEAR')['Data_Value'].mean()

# %%
#df.reset_index()

# %%
#df.plot()

# %%
#df_R = df1.groupby('Race')['Data_Value'].mean()
#df_R

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10600 entries, 0 to 10599
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   YEAR                   10600 non-null  int64
#  1   LocationDesc           10600 non-null  object
#  2   TopicDesc              10600 non-null  object
#  3   Response               8190 non-null   object
#  4   Data_Value_Unit        10600 non-null  object
#  5   Data_Value             10080 non-null  float64
#  6   Data_Value_Std_Err     10080 non-null  float64
#  7   Low_Confidence_Limit   10083 non-null  float64
#  8   High_Confidence_Limit  10080 non-null  float64
#  9   Sample_Size            10080 non-null  float64
#  10  Gender                 10600 non-null  object
#  11  Race                   10600 non-null  object
#  12  Age                    10600 non-null  object
#  13  Education              10600 non-null  object
# ...

# %%
df2 = df2.set_index('YEAR')

# %%
df2=df2[['Data_Value', 'Sample_Size', 'Race', 'Education']]
df2
# Out:
#       Data_Value  Sample_Size       Race      Education
# YEAR
# 2004        32.2       1377.0  All Races  Middle School
# 2008        47.8        654.0  All Races    High School
# 2015        12.7        781.0  All Races    High School
# 2005        28.5       1323.0  All Races  Middle School
# 2005        20.5        973.0  All Races    High School
# ...          ...          ...        ...            ...
# 2002         0.3       1481.0  All Races  Middle School
# 2015         2.7       1190.0  All Races    High School
# 2010         NaN          NaN  All Races  Middle School
# 2009        10.1        879.0  All Races  Middle School
# 2010        45.8        969.0  All Races    High School
#
# [10600 rows x 4 columns]

# %%
df2.isnull().sum()
# Out:
# Data_Value     520
# Sample_Size    520
# Race             0
# Education        0
# dtype: int64

# %%
df2['Data_Value'].fillna(df2['Data_Value'].mean(), inplace=True)
df2
# Out:
#       Data_Value  Sample_Size       Race      Education
# YEAR
# 2004   32.200000       1377.0  All Races  Middle School
# 2008   47.800000        654.0  All Races    High School
# 2015   12.700000        781.0  All Races    High School
# 2005   28.500000       1323.0  All Races  Middle School
# 2005   20.500000        973.0  All Races    High School
# ...          ...          ...        ...            ...
# 2002    0.300000       1481.0  All Races  Middle School
# 2015    2.700000       1190.0  All Races    High School
# 2010   20.336806          NaN  All Races  Middle School
# 2009   10.100000        879.0  All Races  Middle School
# 2010   45.800000        969.0  All Races    High School
#
# [10600 rows x 4 columns]

# %%
df1.reset_index()
# Out:
#        YEAR  Data_Value  Sample_Size                           Race  \
# 0      1999   20.900000        116.0                  Multiple Race
# 1      2005   11.800000        230.0               African American
# 2      1997   22.400000        756.0                      All Races
# 3      2007   13.715967        756.0  American Indian/Alaska Native
# 4      2015   13.715967        756.0               African American
# ...     ...         ...          ...                            ...
# 38703  2011    7.200000       1310.0                      All Races
# 38704  2015   13.715967       1310.0                          Asian
# 38705  1995    5.100000        381.0               African American
# 38706  1993    7.600000       3741.0                          White
# 38707  2001   76.700000        759.0                      All Races
#
#            Education
# 0        High School
# 1        High School
# 2        High School
# 3        High School
# 4        High School
# ...

# %%
df1.duplicated()
# Out:
# YEAR
# 1999    False
# 2005    False
# 1997    False
# 2007    False
# 2015    False
#         ...
# 2011    False
# 2015     True
# 1995    False
# 1993    False
# 2001    False
# Length: 38708, dtype: bool

# %%
df1.drop_duplicates(keep=False,inplace=True)
# Out:
# /Users/wencan/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
len(df1)
# Out:
# 30741

# %%
df2.reset_index()
# Out:
#        YEAR  Data_Value  Sample_Size       Race      Education
# 0      2004   32.200000       1377.0  All Races  Middle School
# 1      2008   47.800000        654.0  All Races    High School
# 2      2015   12.700000        781.0  All Races    High School
# 3      2005   28.500000       1323.0  All Races  Middle School
# 4      2005   20.500000        973.0  All Races    High School
# ...     ...         ...          ...        ...            ...
# 10595  2002    0.300000       1481.0  All Races  Middle School
# 10596  2015    2.700000       1190.0  All Races    High School
# 10597  2010   20.336806          NaN  All Races  Middle School
# 10598  2009   10.100000        879.0  All Races  Middle School
# 10599  2010   45.800000        969.0  All Races    High School
#
# [10600 rows x 5 columns]

# %%
df2.duplicated()
# Out:
# YEAR
# 2004    False
# 2008    False
# 2015    False
# 2005    False
# 2005    False
#         ...
# 2002    False
# 2015    False
# 2010     True
# 2009    False
# 2010    False
# Length: 10600, dtype: bool

# %%
df2.drop_duplicates(keep=False, inplace=True)

# %%
#df_merge = df1.merge(df2, on = 'YEAR', how = 'inner')
#df_merge

# %%
df2.isnull().sum()
# Out:
# Data_Value     0
# Sample_Size    0
# Race           0
# Education      0
# dtype: int64

# %%
df2.duplicated()
# Out:
# YEAR
# 2004    False
# 2008    False
# 2015    False
# 2005    False
# 2005    False
#         ...
# 2000    False
# 2002    False
# 2015    False
# 2009    False
# 2010    False
# Length: 9491, dtype: bool

# %%
#df1.join(df2, on='YEAR')

# %%
df = pd.concat([df1, df2])
df
# Out:
#       Data_Value  Sample_Size              Race      Education
# YEAR
# 1999   20.900000        116.0     Multiple Race    High School
# 2005   11.800000        230.0  African American    High School
# 1997   22.400000        756.0         All Races    High School
# 2011    0.200000       1209.0             Asian    High School
# 2007   13.715967       1209.0         All Races    High School
# ...          ...          ...               ...            ...
# 2000   63.200000        191.0         All Races    High School
# 2002    0.300000       1481.0         All Races  Middle School
# 2015    2.700000       1190.0         All Races    High School
# 2009   10.100000        879.0         All Races  Middle School
# 2010   45.800000        969.0         All Races    High School
#
# [40232 rows x 4 columns]

# %%
#select = df['Race'].where(df['Race'].isin(['All Races', 'Multiple Race']))

# %%
#df[~select]

# %%
df = df.apply(lambda row: row[df['Race'].isin(['African American',
       'American Indian/Alaska Native', 'Asian', 'White', 'Hispanic',
       'Pacific Islander'])])

# %%
df.head()
# Out:
#       Data_Value  Sample_Size              Race    Education
# YEAR
# 2005        11.8        230.0  African American  High School
# 2011         0.2       1209.0             Asian  High School
# 2015        14.1       2351.0             White  High School
# 2015        12.5        409.0          Hispanic  High School
# 2017         8.8        193.0             Asian  High School

# %%
df_y = df.groupby('YEAR')['Data_Value'].mean()
df_y
# Out:
# YEAR
# 1993    27.311800
# 1995    19.704021
# 1997    19.863481
# 1999    17.414201
# 2001    15.657522
# 2003    14.846834
# 2005    14.928353
# 2007    13.967645
# 2009    13.029609
# 2011    12.385953
# 2013    11.027694
# 2015    13.304514
# 2017    11.094930
# Name: Data_Value, dtype: float64

# %%
_ = plt.plot(df_y)
_ = plt.xlabel('year')
_ = plt.ylabel('Tobacco use(%)')
_ = plt.title('Youth Tobacco Use Survey')
plt.show()

# %%
#df_A = df['Race'].where(df['Race'].isin('African American'))

# %%
df_R = df.groupby('Race')['Data_Value'].mean()
df_R
# Out:
# Race
# African American                 12.103017
# American Indian/Alaska Native    15.728757
# Asian                            11.528657
# Hispanic                         14.239454
# Pacific Islander                 14.149693
# White                            14.473085
# Name: Data_Value, dtype: float64

# %%
#_ = sns.swarmplot(x = 'Race', y = 'Data_Value', data=df)
#plt.show()

# %%
_ = plt.plot(df_R)
_ = plt.xlabel('Race', )
_ = plt.ylabel('Tobacco use(%)')
_ = plt.title('Youth Tobacco Use Survey')
_ = plt.xticks(rotation=90)
plt.show()

# %%
df1= df.apply(lambda row: row[df['Race'].isin(['African American'])])
df1=df1.reset_index()
#df1.sort_values('YEAR')
df1 = df1.groupby('YEAR', as_index = False)['Data_Value'].mean()
df1.head()
# Out:
#    YEAR  Data_Value
# 0  1993   24.549437
# 1  1995   16.773053
# 2  1997   18.088880
# 3  1999   16.434223
# 4  2001   14.272600

# %%
df2 = df.apply(lambda row: row[df['Race'].isin(['American Indian/Alaska Native'])])
#df2 = df2.reset_index().sort_values('YEAR')
df2 = df2.groupby('YEAR',as_index = False)['Data_Value'].mean()
df2.head()
# Out:
#    Data_Value
# 0   27.360379
# 1   21.927406
# 2   18.812388
# 3   15.892714
# 4   17.789322

# %%
df3 = df.apply(lambda row: row[df['Race'].isin(['Asian'])])
#df3 = df3.reset_index().sort_values('YEAR')
df3 = df.groupby('YEAR', as_index = False)['Data_Value'].mean()
df3.head()
# Out:
#    Data_Value
# 0   27.311800
# 1   19.704021
# 2   19.863481
# 3   17.414201
# 4   15.657522

# %%
df4 = df.apply(lambda row: row[df['Race'].isin(['White'])])
#df4 = df4.reset_index().sort_values('YEAR')
df4 = df4.groupby('YEAR', as_index = False)['Data_Value'].mean()
df4.head()
# Out:
#    Data_Value
# 0   37.775388
# 1   26.022030
# 2   27.397953
# 3   22.288889
# 4   17.180479

# %%
df5 = df.apply(lambda row: row[df['Race'].isin(['Hispanic'])])
#df5 = df5.reset_index().sort_values('YEAR')
df5 = df5.groupby('YEAR', as_index = False)['Data_Value'].mean()
df5.head()
# Out:
#    Data_Value
# 0   24.336939
# 1   17.721849
# 2   18.297425
# 3   17.093966
# 4   16.217898

# %%
df6 = df.apply(lambda row: row[df['Race'].isin(['Pacific Islander'])])
#df6 = df6.reset_index().sort_values('YEAR')
df6 = df6.groupby('YEAR', as_index = False)['Data_Value'].mean()
df6.head()
# Out:
#    Data_Value
# 0   13.715967
# 1   13.715967
# 2   13.715967
# 3   15.597164
# 4   14.808640

# %%
'''
fig, ax = plt.subplots(2, 3)
ax[0, 0].plot(df1['YEAR'], df1['Data_Value'])
ax[0, 1].plot(df2['YEAR'], df2['Data_Value'])
ax[0, 2].plot(df3['YEAR'], df3['Data_Value'])
ax[1, 0].plot(df4['YEAR'], df4['Data_Value'])
ax[1, 1].plot(df5['YEAR'], df5['Data_Value'])
ax[1, 2].plot(df6['YEAR'], df6['Data_Value'])
plt.show()
'''
# Out:
# "\nfig, ax = plt.subplots(2, 3)\nax[0, 0].plot(df1['YEAR'], df1['Data_Value'])\nax[0, 1].plot(df2['YEAR'], df2['Data_Value'])\nax[0, 2].plot(df3['YEAR'], df3['Data_Value'])\nax[1, 0].plot(df4['YEAR'], df4['Data_Value'])\nax[1, 1].plot(df5['YEAR'], df5['Data_Value'])\nax[1, 2].plot(df6['YEAR'], df6['Data_Value'])\nplt.show()\n"

# %%
'''
fig,ax = plt.subplots()
ax.plot(df1['YEAR'], df1['Data_Value'], marker='o', linestyle='--', color='r')
ax.plot(df2['YEAR'], df2['Data_Value'], marker='v', linestyle='-', color='b')
ax.plot(df3['YEAR'], df3['Data_Value'], marker='o', linestyle='--', color='r')
ax.plot(df4['YEAR'], df1['Data_Value'], marker='v', linestyle='-', color='b')
ax.plot(df5['YEAR'], df1['Data_Value'], marker='o', linestyle='--', color='r')
ax.plot(df6['YEAR'], df1['Data_Value'], marker='v', linestyle='-', color='b')
plot.show()
'''
# Out:
# "\nfig,ax = plt.subplots()\nax.plot(df1['YEAR'], df1['Data_Value'], marker='o', linestyle='--', color='r')\nax.plot(df2['YEAR'], df2['Data_Value'], marker='v', linestyle='-', color='b')\nax.plot(df3['YEAR'], df3['Data_Value'], marker='o', linestyle='--', color='r')\nax.plot(df4['YEAR'], df1['Data_Value'], marker='v', linestyle='-', color='b')\nax.plot(df5['YEAR'], df1['Data_Value'], marker='o', linestyle='--', color='r')\nax.plot(df6['YEAR'], df1['Data_Value'], marker='v', linestyle='-', color='b')\nplot.show()\n"

# %%
'''
fig,ax = plt.subplots()
ax.plot(df1, marker='o', linestyle='--', color='r')
ax.plot(df2, marker='v', linestyle='-', color='b')
ax.plot(df3, marker='o', linestyle='--', color='r')
ax.plot(df4, marker='v', linestyle='-', color='b')
ax.plot(df5, marker='o', linestyle='--', color='r')
ax.plot(df6, marker='v', linestyle='-', color='b')
plot.show()
'''
# Out:
# "\nfig,ax = plt.subplots()\nax.plot(df1, marker='o', linestyle='--', color='r')\nax.plot(df2, marker='v', linestyle='-', color='b')\nax.plot(df3, marker='o', linestyle='--', color='r')\nax.plot(df4, marker='v', linestyle='-', color='b')\nax.plot(df5, marker='o', linestyle='--', color='r')\nax.plot(df6, marker='v', linestyle='-', color='b')\nplot.show()\n"

# %%
fig, ax = plt.subplots()
ax.plot(df.sort_values('YEAR').index, df.sort_values('YEAR')['Data_Value'])
plt.show()
